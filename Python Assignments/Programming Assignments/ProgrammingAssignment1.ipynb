# %% [markdown]
# Write a python Prgram to print "Hello Python"?

# %%
print("Hello Python")
# Out:
# Hello Python

# %% [markdown]
# Write a program to do arithmetical operations additon and division?

# %%
a = b = 2
c = a + b
d = a / b
print(c,d)
# Out:
# 4 1.0

# %% [markdown]
# Write a python program to find the area of a triangle?

# %%
height = 10
base = 10
area_of_triangle = (1/2) * base * height
print(area_of_triangle)
# Out:
# 50.0

# %% [markdown]
# Write a python program to swap two varibles?

# %%
var1 = 2
var2 = 3
var1, var2 = var2, var1
print(var1, var2)
# Out:
# 3 2

# %% [markdown]
# Write a python program to generate a random number?

# %%
import random
print(random.randint(0,100))
# Out:
# 63
