# %% [markdown]
# What is the function of a summation junction of a neuron? What is threshold activation
# function?

# %%
"""
We know that the value at a neuron is calculated after multiplying the input with weight then a bias is added and then we feed it to the activation function.
So at the summation junction what happens is that after the product from all of the input and weights from neurons we add them together.
And a threshold activation function is a type which only gives value 1 if a value over a certain threshold is encoutered if not it remains 0.
"""

# %% [markdown]
# What is a step function? What is the difference of step function with threshold function?

# %%
"""
One of the most commonly used activation function where for value higher than 0 we have a value of 1 and lower than that we have 0 as output.

The difference with threshold is that in threshold function we have a variable instead of a fixed value like 0 in step function so other thresholds can be given as per need.
"""

# %% [markdown]
# Explain the McCulloch–Pitts model of neuron.
# <br><br>
# Ans.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
"""
It was the first computational model of neuron for the mankind divided in 2 parts where one part (g) took the inputs and aggregated them and the second part 
perfomed the decision making portion. For the activation function they used the threshold logic.
"""
# Out:
# '\nIt was the first computational model of neuron for the mankind divided in 2 parts where one part (g) took the inputs and aggregated them and the second part \nperfomed the decision making portion. For the activation function they used the threshold logic.\n'

# %% [markdown]
# Explain the ADALINE network model.
# <br><br>
# Answer

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
"""
The Adaline neural network along with the McCulloch–Pitts model of neuron which used a summation function also adds a bias to it and for the updation of weights uses the 
Gradient descent algorithm. The output of this network is a value on a linear function, for catogorical task another activation function(threshold function) was used 
in the step after the linear output is obtained.
"""

# %% [markdown]
# What is the constraint of a simple perceptron? Why it may fail with a real-world data set?

# %%
"""
One of the major problems of the simple perceptron is that it only output 0 or 1.
Another is that it is only capable of solving classification problems which are linearly separable.
It fails with the real-world data set because most real world problems are not linearly separable in nature and may have outliers, multiple probable output 
meaning a lot more complex in nature.
"""

# %% [markdown]
# What is linearly inseparable problem? What is the role of the hidden layer?

# %%
"""
Linearly inseparable problem are as the name suggests can't be separated if we try to separate them using a line, below we can see that the example A can be separated 
by a straight line in 2 distinct section but B cannot be separated in the same fashion. The solution is to try making the data transform in such a way that it can be separated 
or use a non linear function to try separate them, the role of hidden layer is to perform the nonlinear transformatoin of the inputs that enter into the network. They help the 
neural network be able to solve complex problems like how they make the perceptron a universal approximator.
"""
# Out:
# "\nLinearly inseparable problem are as the name suggests can't be separated if we try to separate them using a line, below we can see that the example A can be separated \nby a straight line in 2 distinct section but B cannot be separated in the same fashion. The solution is to try making the data transform in such a way that it can be separated \nor use a non linear function to try separate them, the role of hidden layer is to perform the nonlinear transformatoin of the inputs that enter into the network. They help the \nneural network be able to solve complex problems like how they make the perceptron a universal approximator.\n"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Explain XOR problem in case of a simple perceptron.

# %%
"""
the XOR is not a linearly separble problem and we know that the simple perceptron cannot solve a problem which in linearly inseparable.
"""

# %% [markdown]
# Design a multi-layer perceptron to implement A XOR B.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
"""
The above is the multi-layer perceptron which can be used to implement A XOR B, here what we do is that "(A AND NOT B)OR(B AND NOT A)" both both right and left of OR are solved 
in a hidden neuron node and the Y node performs the OR operation.
"""

# %% [markdown]
# Explain the single-layer feed forward architecture of ANN.

# %%
"""
In a network layer architecture of ANN the simplest one the the single layer feed forward which has input layer whose neurons are all connected with each neuron of the output layer.
The output layer acts as the processing node. The feed forward part means that the flow of the information takes place in one direction(forward) only from input layer to output 
layer.
"""

# %% [markdown]
# Explain the competitive network architecture of ANN.

# %%
"""
In this type of ANN networks the neurons compete on the basis of who represents the input the best is the one who is allowed to learn. This is done so that 
the neurons are trained to be specialised to represent different kinds of inputs as neuron are already good at representing some of the input and as the training
goes on the keeps on getting to learn resulting in them specialising in representing that kind of input.
"""

# %% [markdown]
# Consider a multi-layer feed forward neural network. Enumerate and explain steps in the
# backpropagation algorithm used to train the network.

# %%
"""
1. Input is provided to the network from input layer which passes through the network in defined interconnected paths.
2. These then are precessed using weights which are choosen randomly and after that passed through an activation function.
3. the output of this network is then compared with the expected output in order to obtain the error.
4. using the loss/cost function we calculate how much the weights of the layers needs to be adjusted for better results.
5. this value is then sent back and passess layer by layer through all the neurons updating the weights.
6. all this comes under just 1 epoch which is then repeated until desired output is achieved(error is minimized).
"""

# %% [markdown]
# What are the advantages and disadvantages of neural networks?

# %%
"""
Advantages:
1. ability to learn complex non linear relationships in data so helps in real life problem solving
2. The generalizes well.
3. They do not impose any restriction on the input variable, meaning the input can have heteroskedasticity which basically says it can have high volatility and non-constant 
variance.

disadvantages:
1. they are black box in nature meaning we cannot predict how the output comes like how we can do with the ML algorithms.
2. they need a lot of hardware support to be able to operate.
3. take a lot of time to train which increased really a lot as well increase the size and complexity of data.
"""

# %% [markdown]
# Write short notes on any two of the following:

# %%
"""
ReLU function:
It is a type of activation function which give 0 for all the values less than 0 meaning all negative value and zero inputs are snapped to 0 and the 
positive inputs are forwarded as-is, giving a linealy increasing slope.

Recurrent networks:
Unlike feed forward neural network where the information only flows in forward direction in RNN the output of one neuron contributes in the ouput generate by other neuron of the 
same layer or we can say it remembers what the output is and uses it alongside while calculating its value. It also helps automatically deal with the vanishing gradient problem 
as there is always a value to be added in backpropogation even though the gradient vanishes. 
"""
